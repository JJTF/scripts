# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para las metas 87 y 95
meta_87_data = data[data['META'] == 87]
meta_95_data = data[data['META'] == 95]

# Sumar los valores mensuales para cada meta
monthly_values_meta_87 = meta_87_data[months].sum()
monthly_values_meta_95 = meta_95_data[months].sum()

# Calcular el acumulado mensual para cada meta
cumulative_meta_87 = monthly_values_meta_87.cumsum()
cumulative_meta_95 = monthly_values_meta_95.cumsum()

# Calcular el porcentaje del PIM total para cada acumulado mensual
pim_value_meta_87 = meta_87_data['PIM'].sum()
pim_value_meta_95 = meta_95_data['PIM'].sum()
percentage_cumulative_meta_87 = (cumulative_meta_87 / pim_value_meta_87) * 100
percentage_cumulative_meta_95 = (cumulative_meta_95 / pim_value_meta_95) * 100

# Crear el gráfico de barras apiladas con acumulados mensuales
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the cumulative values for Meta 87 and Meta 95
bar_width = 0.35
index = range(len(months))

bars_meta_87 = ax.bar(index, cumulative_meta_87, bar_width, label='Meta 87')
bars_meta_95 = ax.bar([i + bar_width for i in index], cumulative_meta_95, bar_width, label='Meta 95')

# Adding title and labels
ax.set_title('Acumulado Mensual por Meta 2024')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto Acumulado en S/.')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 87
for bar, value, percentage in zip(bars_meta_87, cumulative_meta_87, percentage_cumulative_meta_87):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}\n{percentage:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Adding text labels on top of the bars for Meta 95
for bar, value, percentage in zip(bars_meta_95, cumulative_meta_95, percentage_cumulative_meta_95):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}\n{percentage:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores mensuales para la meta 87
monthly_values_meta_87 = meta_87_data[months].sum()

# Calcular el acumulado mensual para la meta 87
cumulative_meta_87 = monthly_values_meta_87.cumsum()

# Calcular el porcentaje del PIM total para cada acumulado mensual
pim_value_meta_87 = meta_87_data['PIM'].sum()
percentage_cumulative_meta_87 = (cumulative_meta_87 / pim_value_meta_87) * 100

# Crear el gráfico de barras con acumulados mensuales
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the cumulative values for Meta 87
bar_width = 0.35
index = range(len(months))

bars_meta_87 = ax.bar(index, cumulative_meta_87, bar_width, label='Meta 87')

# Adding title and labels
ax.set_title('Acumulado Mensual Devengado - Meta 87 (2024)')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto Acumulado en S/.')
ax.set_xticks(index)
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 87
for bar, value, percentage in zip(bars_meta_87, cumulative_meta_87, percentage_cumulative_meta_87):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}\n{percentage:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores mensuales para la meta 87
monthly_values_meta_95 = meta_95_data[months].sum()

# Calcular el acumulado mensual para la meta 87
cumulative_meta_95 = monthly_values_meta_95.cumsum()

# Calcular el porcentaje del PIM total para cada acumulado mensual
pim_value_meta_95 = meta_95_data['PIM'].sum()
percentage_cumulative_meta_95 = (cumulative_meta_95 / pim_value_meta_95) * 100

# Crear el gráfico de barras con acumulados mensuales
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the cumulative values for Meta 95
bar_width = 0.35
index = range(len(months))

bars_meta_95 = ax.bar(index, cumulative_meta_95, bar_width, label='Meta 95')

# Adding title and labels
ax.set_title('Acumulado Mensual Devengado - Meta 95 (2024)')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto Acumulado en S/.')
ax.set_xticks(index)
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 87
for bar, value, percentage in zip(bars_meta_95, cumulative_meta_95, percentage_cumulative_meta_95):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}\n{percentage:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores mensuales para la meta 87
monthly_values_meta_87 = meta_87_data[months].sum()

# Calcular el acumulado mensual para la meta 87
cumulative_meta_87 = monthly_values_meta_87.cumsum()

# Calcular el porcentaje del PIM total para cada acumulado mensual
pim_value_meta_87 = meta_87_data['PIM'].sum()
percentage_cumulative_meta_87_pim = (cumulative_meta_87 / pim_value_meta_87) * 100

# Calcular el porcentaje del certificado total para cada acumulado mensual
# Asumiendo que la columna del certificado se llama 'CERTIFICADO'
certificado_value_meta_87 = meta_87_data['CERTIFICADO'].sum()
percentage_cumulative_meta_87_certificado = (cumulative_meta_87 / certificado_value_meta_87) * 100

# Crear el gráfico de barras con acumulados mensuales
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the cumulative values for Meta 87 as percentages
bar_width = 0.35
index = range(len(months))

bars_meta_87_pim = ax.bar(index, percentage_cumulative_meta_87_pim, bar_width, label='Porcentaje del PIM')
bars_meta_87_certificado = ax.bar([i + bar_width for i in index], percentage_cumulative_meta_87_certificado, bar_width, label='Porcentaje del Certificado')

# Adding title and labels
ax.set_title('Acumulado Mensual Devengado - Meta 87 (2024)')
ax.set_xlabel('Meses')
ax.set_ylabel('Porcentaje Acumulado')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 87
for bar, value in zip(bars_meta_87_pim, percentage_cumulative_meta_87_pim):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'{value:.1f}%',
            ha='center', va='bottom', fontsize=12, rotation=90)

for bar, value in zip(bars_meta_87_certificado, percentage_cumulative_meta_87_certificado):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'{value:.1f}%',
            ha='center', va='bottom', fontsize=12, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores mensuales para la meta 95
monthly_values_meta_95 = meta_95_data[months].sum()

# Calcular el acumulado mensual para la meta 95
cumulative_meta_95 = monthly_values_meta_95.cumsum()

# Calcular el porcentaje del PIM total para cada acumulado mensual
pim_value_meta_95 = meta_95_data['PIM'].sum()
percentage_cumulative_meta_95_pim = (cumulative_meta_95 / pim_value_meta_95) * 100

# Calcular el porcentaje del certificado total para cada acumulado mensual
# Asumiendo que la columna del certificado se llama 'CERTIFICADO'
certificado_value_meta_95 = meta_95_data['CERTIFICADO'].sum()
percentage_cumulative_meta_95_certificado = (cumulative_meta_95 / certificado_value_meta_95) * 100

# Crear el gráfico de barras con acumulados mensuales
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the cumulative values for Meta 95 as percentages
bar_width = 0.35
index = range(len(months))

bars_meta_95_pim = ax.bar(index, percentage_cumulative_meta_95_pim, bar_width, label='Porcentaje del PIM')
bars_meta_95_certificado = ax.bar([i + bar_width for i in index], percentage_cumulative_meta_95_certificado, bar_width, label='Porcentaje del Certificado')

# Adding title and labels
ax.set_title('Acumulado Mensual Devengado - Meta 95 (2024)')
ax.set_xlabel('Meses')
ax.set_ylabel('Porcentaje Acumulado')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 95
for bar, value in zip(bars_meta_95_pim, percentage_cumulative_meta_95_pim):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'{value:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

for bar, value in zip(bars_meta_95_certificado, percentage_cumulative_meta_95_certificado):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'{value:.1f}%',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores mensuales para cada GENERICA y META 87
monthly_values_meta_87_personal = meta_87_data[meta_87_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES'][months].sum()
monthly_values_meta_87_bienes = meta_87_data[meta_87_data['GENERICA'] == '3.BIENES Y SERVICIOS'][months].sum()

# Crear el gráfico de barras para la Meta 87
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the bars for different GENERICA in Meta 87
bar_width = 0.35
index = range(len(months))

bars_meta_87_personal = ax.bar(index, monthly_values_meta_87_personal, bar_width, label='Personal y Obligaciones Sociales')
bars_meta_87_bienes = ax.bar([i + bar_width for i in index], monthly_values_meta_87_bienes, bar_width, label='Bienes y Servicios')

# Adding title and labels
ax.set_title('Seguimiento al Presupuesto 2024 - Meta 87 por Generica')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto en S/.')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend()

# Adding text labels on top of the bars for Meta 87 - Personal y Obligaciones Sociales
for bar, value in zip(bars_meta_87_personal, monthly_values_meta_87_personal):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Adding text labels on top of the bars for Meta 87 - Bienes y Servicios
for bar, value in zip(bars_meta_87_bienes, monthly_values_meta_87_bienes):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores mensuales para cada GENERICA y META 87
monthly_values_meta_87_personal = meta_87_data[meta_87_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES'][months].sum()
monthly_values_meta_87_bienes = meta_87_data[meta_87_data['GENERICA'] == '3.BIENES Y SERVICIOS'][months].sum()

# Crear el gráfico de barras para la Meta 87
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the bars for different GENERICA in Meta 87
bar_width = 0.35
index = range(len(months))

bars_meta_87_personal = ax.bar(index, monthly_values_meta_87_personal, bar_width, label='Personal y Obligaciones Sociales (PIM: S/. 2373692)')
bars_meta_87_bienes = ax.bar([i + bar_width for i in index], monthly_values_meta_87_bienes, bar_width, label='Bienes y Servicios (PIM: S/. 287100)')

# Adding title and labels
ax.set_title('Seguimiento al Presupuesto 2024 - Meta 87 por Generica')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto en S/.')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend(title=f'Total PIM Meta 87: S/. 2660792')

# Adding text labels on top of the bars for Meta 87 - Personal y Obligaciones Sociales
for bar, value in zip(bars_meta_87_personal, monthly_values_meta_87_personal):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Adding text labels on top of the bars for Meta 87 - Bienes y Servicios
for bar, value in zip(bars_meta_87_bienes, monthly_values_meta_87_bienes):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Meses
months = ["ENERO", "FEBRERO", "MARZO", "ABRIL", "MAYO", "JUNIO",
          "JULIO", "AGOSTO", "SETIEMBRE", "OCTUBRE", "NOVIEMBRE", "DICIEMBRE"]

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores mensuales para cada GENERICA y META 87
monthly_values_meta_87_personal = meta_87_data[meta_87_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES'][months].sum()
monthly_values_meta_87_bienes = meta_87_data[meta_87_data['GENERICA'] == '3.BIENES Y SERVICIOS'][months].sum()

# Crear el gráfico de barras para la Meta 87
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the bars for different GENERICA in Meta 87
bar_width = 0.35
index = range(len(months))

bars_meta_87_personal = ax.bar(index, monthly_values_meta_87_personal, bar_width, label='Personal y Obligaciones Sociales (PIM: S/. 2373692)')
bars_meta_87_bienes = ax.bar([i + bar_width for i in index], monthly_values_meta_87_bienes, bar_width, label='Bienes y Servicios (PIM: S/. 287100)')

# Adding title and labels
ax.set_title('Seguimiento al Presupuesto 2024 - Meta 87 por Generica')
ax.set_xlabel('Meses')
ax.set_ylabel('Monto en S/.')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(months, rotation=90)
ax.legend(title=f'Total PIM Meta 87: S/. 2660792')

# Adding text labels on top of the bars for Meta 87 - Personal y Obligaciones Sociales
for bar, value in zip(bars_meta_87_personal, monthly_values_meta_87_personal):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Adding text labels on top of the bars for Meta 87 - Bienes y Servicios
for bar, value in zip(bars_meta_87_bienes, monthly_values_meta_87_bienes):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'S/. {value:.2f}',
            ha='center', va='bottom', fontsize=10, rotation=90)

# Mostrar el gráfico
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Filtrar los datos para la meta 87
meta_87_data = data[data['META'] == 87]

# Sumar los valores de PIM para cada GENERICA y META 87
pim_meta_87_personal = meta_87_data[meta_87_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES']['PIM'].sum()
pim_meta_87_bienes = meta_87_data[meta_87_data['GENERICA'] == '3.BIENES Y SERVICIOS']['PIM'].sum()
total_pim_meta_87 = pim_meta_87_personal + pim_meta_87_bienes

# Calcular el porcentaje de cada GENERICA para META 87
percent_meta_87_personal = (pim_meta_87_personal / total_pim_meta_87) * 100
percent_meta_87_bienes = (pim_meta_87_bienes / total_pim_meta_87) * 100

# Crear gráfico de pastel para META 87
labels_meta_87 = [
    f'Personal y Obligaciones Sociales (S/. {pim_meta_87_personal:.2f}) - {percent_meta_87_personal:.1f}%',
    f'Bienes y Servicios (S/. {pim_meta_87_bienes:.2f}) - {percent_meta_87_bienes:.1f}%'
]
sizes_meta_87 = [percent_meta_87_personal, percent_meta_87_bienes]

fig1, ax1 = plt.subplots()
ax1.pie(sizes_meta_87, labels=labels_meta_87, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribución del PIM por Generica - Meta 87')
plt.show()

# %%
# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada GENERICA y META 95
pim_meta_95_personal = meta_95_data[meta_95_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES']['PIM'].sum()
pim_meta_95_bienes = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS']['PIM'].sum()
pim_meta_95_activos = meta_95_data[meta_95_data['GENERICA'] == '6.ADQUISICION DE ACTIVOS NO FINANCIEROS']['PIM'].sum()
total_pim_meta_95 = pim_meta_95_personal + pim_meta_95_bienes + pim_meta_95_activos

# Calcular el porcentaje de cada GENERICA para META 95
percent_meta_95_personal = (pim_meta_95_personal / total_pim_meta_95) * 100
percent_meta_95_bienes = (pim_meta_95_bienes / total_pim_meta_95) * 100
percent_meta_95_activos = (pim_meta_95_activos / total_pim_meta_95) * 100

# Crear gráfico de pastel para META 95
labels_meta_95 = [
    f'Personal y Obligaciones Sociales (S/. {pim_meta_95_personal:.2f}) - {percent_meta_95_personal:.1f}%',
    f'Bienes y Servicios (S/. {pim_meta_95_bienes:.2f}) - {percent_meta_95_bienes:.1f}%',
    f'Adquisición de Activos No Financieros (S/. {pim_meta_95_activos:.2f}) - {percent_meta_95_activos:.1f}%'
]
sizes_meta_95 = [percent_meta_95_personal, percent_meta_95_bienes, percent_meta_95_activos]

fig2, ax2 = plt.subplots()
ax2.pie(sizes_meta_95, labels=labels_meta_95, autopct='%1.1f%%', startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribución del PIM por Generica - Meta 95')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Filtrar los datos para las metas 87 y 95
meta_87_data = data[data['META'] == 87]
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada GENERICA y META 87
pim_meta_87_personal = meta_87_data[meta_87_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES']['PIM'].sum()
pim_meta_87_bienes = meta_87_data[meta_87_data['GENERICA'] == '3.BIENES Y SERVICIOS']['PIM'].sum()
total_pim_meta_87 = pim_meta_87_personal + pim_meta_87_bienes

# Calcular el porcentaje de cada GENERICA para META 87
percent_meta_87_personal = (pim_meta_87_personal / total_pim_meta_87) * 100
percent_meta_87_bienes = (pim_meta_87_bienes / total_pim_meta_87) * 100

# Crear gráfico de pastel para META 87
labels_meta_87 = [
    f'Personal y Obligaciones Sociales (S/. {pim_meta_87_personal:.2f}) - {percent_meta_87_personal:.1f}%',
    f'Bienes y Servicios (S/. {pim_meta_87_bienes:.2f}) - {percent_meta_87_bienes:.1f}%'
]
sizes_meta_87 = [percent_meta_87_personal, percent_meta_87_bienes]

fig1, ax1 = plt.subplots()
ax1.pie(sizes_meta_87, labels=labels_meta_87, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribución del PIM por Generica - Meta 87')
plt.show()

# Sumar los valores de PIM para cada GENERICA y META 95
pim_meta_95_personal = meta_95_data[meta_95_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES']['PIM'].sum()
pim_meta_95_bienes = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS']['PIM'].sum()
pim_meta_95_activos = meta_95_data[meta_95_data['GENERICA'] == '6.ADQUISICION DE ACTIVOS NO FINANCIEROS']['PIM'].sum()
total_pim_meta_95 = pim_meta_95_personal + pim_meta_95_bienes + pim_meta_95_activos

# Calcular el porcentaje de cada GENERICA para META 95
percent_meta_95_personal = (pim_meta_95_personal / total_pim_meta_95) * 100
percent_meta_95_bienes = (pim_meta_95_bienes / total_pim_meta_95) * 100
percent_meta_95_activos = (pim_meta_95_activos / total_pim_meta_95) * 100

# Crear gráfico de pastel para META 95
labels_meta_95 = [
    f'Personal y Obligaciones Sociales (S/. {pim_meta_95_personal:.2f}) - {percent_meta_95_personal:.1f}%',
    f'Bienes y Servicios (S/. {pim_meta_95_bienes:.2f}) - {percent_meta_95_bienes:.1f}%',
    f'Adquisición de Activos No Financieros (S/. {pim_meta_95_activos:.2f}) - {percent_meta_95_activos:.1f}%'
]
sizes_meta_95 = [percent_meta_95_activos, percent_meta_95_personal, percent_meta_95_bienes]

fig2, ax2 = plt.subplots()
ax2.pie(sizes_meta_95, labels=labels_meta_95, autopct='%1.1f%%', startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# Out:
# (-1.09999979123043,
#  1.0999998581252712,
#  -1.0999999946436734,
#  1.0999999997449368)

# %%
# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada GENERICA y META 95
pim_meta_95_personal = meta_95_data[meta_95_data['GENERICA'] == '1.PERSONAL Y OBLIGACIONES SOCIALES']['PIM'].sum()
pim_meta_95_bienes = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS']['PIM'].sum()
pim_meta_95_activos = meta_95_data[meta_95_data['GENERICA'] == '6.ADQUISICION DE ACTIVOS NO FINANCIEROS']['PIM'].sum()
total_pim_meta_95 = pim_meta_95_personal + pim_meta_95_bienes + pim_meta_95_activos

# Calcular el porcentaje de cada GENERICA para META 95
percent_meta_95_personal = (pim_meta_95_personal / total_pim_meta_95) * 100
percent_meta_95_bienes = (pim_meta_95_bienes / total_pim_meta_95) * 100
percent_meta_95_activos = (pim_meta_95_activos / total_pim_meta_95) * 100

# Crear gráfico de pastel para META 95
labels_meta_95 = [
    f'Adquisición de Activos No Financieros (S/. {pim_meta_95_activos:.2f}) - {percent_meta_95_activos:.1f}%',
    f'Personal y Obligaciones Sociales (S/. {pim_meta_95_personal:.2f}) - {percent_meta_95_personal:.1f}%',
    f'Bienes y Servicios (S/. {pim_meta_95_bienes:.2f}) - {percent_meta_95_bienes:.1f}%'
]
sizes_meta_95 = [percent_meta_95_activos, percent_meta_95_personal, percent_meta_95_bienes]

# Ajustar las opciones de visualización del gráfico para resaltar mejor la parte pequeña
fig2, ax2 = plt.subplots()
ax2.pie(sizes_meta_95, labels=labels_meta_95, autopct='%1.1f%%', startangle=90,
        pctdistance=0.85, explode=(0.1, 0, 0))

# Añadir un círculo blanco en el centro para crear un gráfico de dona
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig2.gca().add_artist(centre_circle)

# Asegurar que el gráfico de dona sea circular
ax2.axis('equal')

plt.title('Distribución del PIM por Generica - Meta 95')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
pim_meta_95_bienes_clasificador = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS'].groupby('CLASIFICADOR1')['PIM'].sum()

# Calcular el porcentaje de cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
total_pim_meta_95_bienes = pim_meta_95_bienes_clasificador.sum()
percent_meta_95_bienes_clasificador = (pim_meta_95_bienes_clasificador / total_pim_meta_95_bienes) * 100

# Crear gráfico de pastel para desglosar "Bienes y Servicios" en la META 95
labels_meta_95_bienes = [f'{clas} (S/. {pim:.2f}) - {perc:.1f}%' for clas, pim, perc in zip(pim_meta_95_bienes_clasificador.index, pim_meta_95_bienes_clasificador, percent_meta_95_bienes_clasificador)]
sizes_meta_95_bienes = percent_meta_95_bienes_clasificador

fig3, ax3 = plt.subplots()
ax3.pie(sizes_meta_95_bienes, labels=labels_meta_95_bienes, autopct='%1.1f%%', startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribución del PIM por Clasificador1 - Meta 95 (Bienes y Servicios)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
pim_meta_95_bienes_clasificador = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS'].groupby('CLASIFICADOR1')['PIM'].sum()

# Calcular el porcentaje de cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
total_pim_meta_95_bienes = pim_meta_95_bienes_clasificador.sum()
percent_meta_95_bienes_clasificador = (pim_meta_95_bienes_clasificador / total_pim_meta_95_bienes) * 100

# Limpiar los nombres de los clasificadores (eliminando los números que anteceden al clasificador)
cleaned_labels = pim_meta_95_bienes_clasificador.index.str.replace(r'^\d+\.', '', regex=True)

# Crear gráfico de dona para desglosar "Bienes y Servicios" en la META 95
labels_meta_95_bienes = [f'{clas} (S/. {pim:.2f}) - {perc:.1f}%' for clas, pim, perc in zip(cleaned_labels, pim_meta_95_bienes_clasificador, percent_meta_95_bienes_clasificador)]
sizes_meta_95_bienes = percent_meta_95_bienes_clasificador

fig3, ax3 = plt.subplots()
ax3.pie(sizes_meta_95_bienes, labels=labels_meta_95_bienes, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode=[0.05]*len(sizes_meta_95_bienes))

# Añadir un círculo blanco en el centro para crear un gráfico de dona
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig3.gca().add_artist(centre_circle)

# Asegurar que el gráfico de dona sea circular
ax3.axis('equal')

plt.title('Distribución del PIM por Clasificador1 - Meta 95 (Bienes y Servicios)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'
data = pd.read_excel(file_path)

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
pim_meta_95_bienes_clasificador = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS'].groupby('CLASIFICADOR1')['PIM'].sum()

# Calcular el porcentaje de cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
total_pim_meta_95_bienes = pim_meta_95_bienes_clasificador.sum()
percent_meta_95_bienes_clasificador = (pim_meta_95_bienes_clasificador / total_pim_meta_95_bienes) * 100

# Limpiar los nombres de los clasificadores (eliminando los números que anteceden al clasificador)
cleaned_labels = pim_meta_95_bienes_clasificador.index.str.replace(r'^\d+\.', '', regex=True)

# Crear gráfico de dona para desglosar "Bienes y Servicios" en la META 95
labels_meta_95_bienes = [f'{clas} (S/. {pim:.2f}) - {perc:.1f}%' for clas, pim, perc in zip(cleaned_labels, pim_meta_95_bienes_clasificador, percent_meta_95_bienes_clasificador)]
sizes_meta_95_bienes = percent_meta_95_bienes_clasificador

fig3, ax3 = plt.subplots()
ax3.pie(sizes_meta_95_bienes, labels=labels_meta_95_bienes, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode=[0.05]*len(sizes_meta_95_bienes))

# Añadir un círculo blanco en el centro para crear un gráfico de dona
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig3.gca().add_artist(centre_circle)

# Asegurar que el gráfico de dona sea circular
ax3.axis('equal')

plt.title('Distribución del PIM por Clasificador1 - Meta 95 (Bienes y Servicios)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo Excel
file_path = '/content/bd_poi_ene_may_2024.xlsx'  # Reemplaza con la ruta correcta de tu archivo
data = pd.read_excel(file_path)

# Filtrar los datos para la meta 95
meta_95_data = data[data['META'] == 95]

# Sumar los valores de PIM para cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
pim_meta_95_bienes_clasificador = meta_95_data[meta_95_data['GENERICA'] == '3.BIENES Y SERVICIOS'].groupby('CLASIFICADOR1')['PIM'].sum()

# Calcular el porcentaje de cada CLASIFICADOR1 dentro de la GENERICA "3.BIENES Y SERVICIOS" para la META 95
total_pim_meta_95_bienes = pim_meta_95_bienes_clasificador.sum()
percent_meta_95_bienes_clasificador = (pim_meta_95_bienes_clasificador / total_pim_meta_95_bienes) * 100

# Limpiar los nombres de los clasificadores (eliminando los números que anteceden al clasificador)
cleaned_labels = pim_meta_95_bienes_clasificador.index.str.replace(r'^\d+\.', '', regex=True)

# Crear gráfico de dona para desglosar "Bienes y Servicios" en la META 95
labels_meta_95_bienes = [f'{clas} (S/. {pim:.2f}) - {perc:.1f}%' for clas, pim, perc in zip(cleaned_labels, pim_meta_95_bienes_clasificador, percent_meta_95_bienes_clasificador)]
sizes_meta_95_bienes = percent_meta_95_bienes_clasificador

fig3, ax3 = plt.subplots()
ax3.pie(sizes_meta_95_bienes, labels=labels_meta_95_bienes, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode=[0.05]*len(sizes_meta_95_bienes))

# Añadir un círculo blanco en el centro para crear un gráfico de dona
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig3.gca().add_artist(centre_circle)

# Asegurar que el gráfico de dona sea circular
ax3.axis('equal')

plt.title('Distribución del PIM por Clasificador1 - Meta 95 (Bienes y Servicios)')
plt.show()
